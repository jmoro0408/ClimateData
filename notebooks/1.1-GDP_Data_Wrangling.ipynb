# %%
import pandas as pd
from pathlib import Path

# %%
GDP_DATA = r"/Users/jamesmoro/Documents/Python/ClimateData/data/raw/Country_GDP_data/API_NY.GDP.MKTP.CD_DS2_en_excel_v2_3158925.xls"
SAVE_DIR = r"/Users/jamesmoro/Documents/Python/ClimateData/data/interim"

# %%
gdp_df = pd.read_excel(GDP_DATA)

# %%
gdp_df.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2021-10-28 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0                NaN             NaN           NaN           NaN
# 1                NaN             NaN           NaN           NaN
# 2     Indicator Name  Indicator Code  1.960000e+03  1.961000e+03
# 3  GDP (current US$)  NY.GDP.MKTP.CD           NaN           NaN
# 4  GDP (current US$)  NY.GDP.MKTP.CD  1.934248e+10  1.975349e+10
#
#      Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...   Unnamed: 55  \
# 0           NaN           NaN           NaN           NaN  ...           NaN
# ...

# %%
gdp_df.drop([0,1], axis=0, inplace = True)

# %%
gdp_df.head()
# Out:
#                    Data Source World Development Indicators  \
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
# 5                  Afghanistan                          AFG
# 6   Africa Western and Central                          AFW
#
#           Unnamed: 2      Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 2     Indicator Name  Indicator Code  1.960000e+03  1.961000e+03
# 3  GDP (current US$)  NY.GDP.MKTP.CD           NaN           NaN
# 4  GDP (current US$)  NY.GDP.MKTP.CD  1.934248e+10  1.975349e+10
# 5  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08
# 6  GDP (current US$)  NY.GDP.MKTP.CD  1.040732e+10  1.113130e+10
#
#      Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...   Unnamed: 55  \
# 2  1.962000e+03  1.963000e+03  1.964000e+03  1.965000e+03  ...  2.011000e+03
# ...

# %%
new_header = gdp_df.iloc[0] #grab the first row for the header
gdp_df= gdp_df[1:] #take the data less the header row
gdp_df.columns = new_header
gdp_df.head()
# Out:
# 2                 Country Name Country Code     Indicator Name  \
# 3                        Aruba          ABW  GDP (current US$)
# 4  Africa Eastern and Southern          AFE  GDP (current US$)
# 5                  Afghanistan          AFG  GDP (current US$)
# 6   Africa Western and Central          AFW  GDP (current US$)
# 7                       Angola          AGO  GDP (current US$)
#
# 2  Indicator Code        1960.0        1961.0        1962.0        1963.0  \
# 3  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 4  NY.GDP.MKTP.CD  1.934248e+10  1.975349e+10  2.152662e+10  2.577236e+10
# 5  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 6  NY.GDP.MKTP.CD  1.040732e+10  1.113130e+10  1.194684e+10  1.268022e+10
# 7  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
# 2        1964.0        1965.0  ...        2011.0        2012.0        2013.0  \
# ...

# %%
gdp_df_reduced = gdp_df.drop(columns = ["Country Code", "Indicator Name", "Indicator Code"])

# %%
gdp_df_reduced.drop("Country Name", axis =1).isna().sum().idxmin() # Year with the least missing values
# Out:
# 2011.0

# %%
gdp_df_reduced.drop("Country Name", axis =1).isna().sum()
# Out:
# 2
# 1960.0    134
# 1961.0    133
# 1962.0    130
# 1963.0    130
# 1964.0    130
#          ...
# 2016.0     12
# 2017.0     12
# 2018.0     12
# 2019.0     19
# 2020.0     41
# Length: 61, dtype: int64

# %%
gdp_df_reduced[2011].isna().sum()

#2018 only has two more missing values than 2010 and is much more up to date
# Out:
# 10

# %%
gdp_reduced_final = gdp_df_reduced[["Country Name",2018]]

# %%
file_path = Path(SAVE_DIR, "Country_GDP_data.pkl")

pd.to_pickle(gdp_reduced_final, file_path)
